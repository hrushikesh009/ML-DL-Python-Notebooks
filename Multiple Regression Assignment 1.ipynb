# %%
pip install turicreate

# %%
import turicreate as tc

# %%
sales = tc.SFrame('/content/drive/My Drive/home_data.sframe')
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
training_data,test_data = sales.random_split(.8,seed=0)

# %%
example_features = ['sqft_living', 'bedrooms', 'bathrooms']
example_model = tc.linear_regression.create(training_data, target = 'price', features = example_features, 
                                                    validation_set = None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 3
# Number of unpacked features : 3
# Number of coefficients    : 4
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.021661     | 4146407.600631     | 258679.804477                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
example_weight_summary = example_model.coefficients
print (example_weight_summary)
# Out:
# +-------------+-------+--------------------+--------------------+
# |     name    | index |       value        |       stderr       |
# +-------------+-------+--------------------+--------------------+
# | (intercept) |  None | 87910.07249239809  | 7873.338143401673  |
# | sqft_living |  None |   315.4034405521   | 3.455700325854743  |
# |   bedrooms  |  None | -65080.21555282686 | 2717.456854420703  |
# |  bathrooms  |  None | 6944.020192636717  | 3923.1149314414993 |
# +-------------+-------+--------------------+--------------------+
# [4 rows x 4 columns]

# %%
example_predictions = example_model.predict(training_data)
print (example_predictions[0]) # should be 271789.505878
# Out:
# 271789.5058780322

# %%
def get_residual_sum_of_squares(model, data, outcome):
    # First get the predictions
      predictions = model.predict(data)
    # Then compute the residuals/errors
      residuals_errors = outcome - predictions
    # Then square and add them up
      values = residuals_errors*residuals_errors
      RSS = values.sum()
      return(RSS)

# %%
rss_example_train = get_residual_sum_of_squares(example_model, test_data, test_data['price'])
print (rss_example_train) # should be 2.7376153833e+14
# Out:
# 273761538330193.2

# %%
from math import log

# %%
training_data['bedrooms_squared'] = training_data['bedrooms'].apply(lambda x: x**2)
test_data['bedrooms_squared'] = test_data['bedrooms'].apply(lambda x: x**2)

# %%
training_data['bed_bath_rooms'] = training_data['bedrooms'] * training_data['bathrooms']
test_data['bed_bath_rooms'] = test_data['bedrooms'] * test_data['bathrooms']

# %%
training_data['log_sqft_living'] = training_data['sqft_living'].apply(lambda x: log(x))
test_data['log_sqft_living'] = test_data['sqft_living'].apply(lambda x: log(x))

# %%
training_data['lat_plus_long'] = training_data['lat'] + training_data['long']
test_data['lat_plus_long'] = test_data['lat'] + test_data['long']

# %%
print(test_data['bedrooms_squared'].mean())
print(test_data['bed_bath_rooms'].mean())
print(test_data['log_sqft_living'].mean())
print(test_data['lat_plus_long'].mean())
# Out:
# 12.4466777015843
# 7.503901631591395
# 7.550274679645938
# -74.65333497217313

# %%
model_1_features = [ 'sqft_living', 'bedrooms', 'bathrooms', 'lat','long']
model_1 = tc.linear_regression.create(training_data, target = 'price', features =model_1_features, 
                                                    validation_set = None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 5
# Number of unpacked features : 5
# Number of coefficients    : 6
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.021932     | 4074878.213103     | 236378.596455                   |
# | 2         | 3        | 0.040450     | 4074878.213108     | 236378.596455                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
model_1.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 6
#
# Data:
# +-------------+-------+---------------------+--------------------+
# |     name    | index |        value        |       stderr       |
# +-------------+-------+---------------------+--------------------+
# | (intercept) |  None | -56140675.741145164 | 1649985.420232753  |
# | sqft_living |  None |  310.26332577692176 | 3.188829604072599  |
# |   bedrooms  |  None |  -59577.11606759663 | 2487.279773224208  |
# |  bathrooms  |  None |  13811.840541653299 | 3593.5421329676874 |
# |     lat     |  None |  629865.7894714857  | 13120.71003228041  |
# |     long    |  None | -214790.28516471686 | 13284.285159947443 |
# +-------------+-------+---------------------+--------------------+
# [6 rows x 4 columns]

# %%
model_2_features = [ 'sqft_living', 'bedrooms', 'bathrooms', 'lat','long','bed_bath_rooms']
model_2 = tc.linear_regression.create(training_data, target = 'price', features =model_2_features, 
                                                    validation_set = None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 7
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.021470     | 4014170.932940     | 235190.935428                   |
# | 2         | 3        | 0.050282     | 4014170.932936     | 235190.935429                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
model_2.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 7
#
# Data:
# +----------------+-------+---------------------+--------------------+
# |      name      | index |        value        |       stderr       |
# +----------------+-------+---------------------+--------------------+
# |  (intercept)   |  None |  -54410676.11184308 | 1650405.1653694494 |
# |  sqft_living   |  None |  304.44929805557945 | 3.202175356366349  |
# |    bedrooms    |  None | -116366.04322944838 | 4805.549665484017  |
# |   bathrooms    |  None |  -77972.33051298767 | 7565.059910947668  |
# |      lat       |  None |  625433.8349398111  | 13058.353097203788 |
# |      long      |  None | -203958.60293748273 | 13268.128370376078 |
# | bed_bath_rooms |  None |  26961.624908952057 | 1956.3656155583221 |
# +----------------+-------+---------------------+--------------------+
# [7 rows x 4 columns]

# %%
model_3_features = [ 'sqft_living', 'bedrooms', 'bathrooms', 'lat','long','bed_bath_rooms','bedrooms_squared','log_sqft_living','lat_plus_long']
model_3 = tc.linear_regression.create(training_data, target = 'price', features =model_3_features, 
                                                    validation_set = None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 9
# Number of unpacked features : 9
# Number of coefficients    : 10
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.029449     | 3193229.177888     | 228200.043155                   |
# | 2         | 3        | 0.059335     | 3193229.177873     | 228200.043155                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
model_3.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 10
#
# Data:
# +------------------+-------+---------------------+--------------------+
# |       name       | index |        value        |       stderr       |
# +------------------+-------+---------------------+--------------------+
# |   (intercept)    |  None | -52974974.068921715 | 1615194.9446730777 |
# |   sqft_living    |  None |  529.1964205687524  | 7.699134985121209  |
# |     bedrooms     |  None |   28948.5277463525  | 9395.728891147388  |
# |    bathrooms     |  None |  65661.20723969756  | 10795.338070257121 |
# |       lat        |  None |  704762.1484430789  | 787087632.0068617  |
# |       long       |  None | -137780.02000718215 |  787087632.297173  |
# |  bed_bath_rooms  |  None |  -8478.364107167637 | 2858.9539125683445 |
# | bedrooms_squared |  None | -6072.3846619051355 | 1494.9704277890871 |
# | log_sqft_living  |  None |  -563467.7842801766 | 17567.82308147047  |
# ...

# %%
get_residual_sum_of_squares(model_1,training_data,training_data['price'])
# Out:
# 971328233545435.4

# %%
get_residual_sum_of_squares(model_2,training_data,training_data['price'])
# Out:
# 961592067857506.0

# %%
get_residual_sum_of_squares(model_3,training_data,training_data['price'])
# Out:
# 905276314551642.5

# %%
get_residual_sum_of_squares(model_1,test_data,test_data['price'])
# Out:
# 226568089093160.38

# %%
get_residual_sum_of_squares(model_2,test_data,test_data['price'])
# Out:
# 224368799993971.25

# %%
get_residual_sum_of_squares(model_3,test_data,test_data['price'])
# Out:
# 251829318963159.2
