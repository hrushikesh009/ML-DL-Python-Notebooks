# %%
import gc
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
import lightgbm as lgb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # The Data

# %% [markdown]
# Split the dataset in to train and test. We are using training data only for EDA.

# %%
df = pd.read_csv('/content/drive/My Drive/train.tsv', sep = '\t')

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
train.shape, test.shape
# Out:
# ((1186063, 8), (296472, 8))

# %% [markdown]
# # EDA

# %%
train.head()
# Out:
#    train_id  ...                                   item_description
# 0         0  ...                                 No description yet
# 1         1  ...  This keyboard is in great condition and works ...
# 2         2  ...  Adorable top with a hint of lace and a key hol...
# 3         3  ...  New with tags. Leather horses. Retail for [rm]...
# 5         5  ...  Banana republic bottoms, Candies skirt with ma...
#
# [5 rows x 8 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1186063 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1186063 non-null  int64
#  1   name               1186063 non-null  object
#  2   item_condition_id  1186063 non-null  int64
#  3   category_name      1181007 non-null  object
#  4   brand_name         680129 non-null   object
#  5   price              1186063 non-null  float64
#  6   shipping           1186063 non-null  int64
#  7   item_description   1186059 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 81.4+ MB

# %% [markdown]
# ## Price

# %%
train.price.describe()
# Out:
# count    1.186063e+06
# mean     2.675181e+01
# std      3.863994e+01
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.700000e+01
# 75%      2.900000e+01
# max      2.009000e+03
# Name: price, dtype: float64

# %%
plt.subplot(1, 2, 1)
(train['price']).plot.hist(bins=50, figsize=(12, 6), edgecolor = 'white', range = [0, 250])
plt.xlabel('price', fontsize=12)
plt.title('Price Distribution', fontsize=12)

plt.subplot(1, 2, 2)
np.log(train['price']+1).plot.hist(bins=50, figsize=(12,6), edgecolor='white')
plt.xlabel('log(price+1)', fontsize=12)
plt.title('Price Distribution', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %% [markdown]
# The price of items are left skewed, vast majority of items priced at 10-20. However, the most expensive item priced at 2009. So we make log-transformation on the price.

# %% [markdown]
# ## Shipping

# %%
train['shipping'].value_counts() / len(train)
# Out:
# 0    0.552739
# 1    0.447261
# Name: shipping, dtype: float64

# %% [markdown]
# Over 55% of items shipping fee were paid by the buyers. How shipping related to price?

# %%
shipping_fee_by_buyer = train.loc[df['shipping'] == 0, 'price']
shipping_fee_by_seller = train.loc[df['shipping'] == 1, 'price']

fig, ax = plt.subplots(figsize=(18,8))
ax.hist(shipping_fee_by_seller, color='#8CB4E1', alpha=1.0, bins=50, range = [0, 100],
       label='Price when Seller pays Shipping')
ax.hist(shipping_fee_by_buyer, color='#007D00', alpha=0.7, bins=50, range = [0, 100],
       label='Price when Buyer pays Shipping')
plt.xlabel('price', fontsize=12)
plt.ylabel('frequency', fontsize=12)
plt.title('Price Distribution by Shipping Type', fontsize=15)
plt.tick_params(labelsize=12)
plt.legend()
plt.show()

# %%
print('The average price is {}'.format(round(shipping_fee_by_seller.mean(), 2)), 'if seller pays shipping');
print('The average price is {}'.format(round(shipping_fee_by_buyer.mean(), 2)), 'if buyer pays shipping')
# Out:
# The average price is 22.59 if seller pays shipping
# The average price is 30.12 if buyer pays shipping

# %% [markdown]
# We compare again after log-transformation on the price.

# %%
fig, ax = plt.subplots(figsize=(18,8))
ax.hist(np.log(shipping_fee_by_seller+1), color='#8CB4E1', alpha=1.0, bins=50,
       label='Price when Seller pays Shipping')
ax.hist(np.log(shipping_fee_by_buyer+1), color='#007D00', alpha=0.7, bins=50,
       label='Price when Buyer pays Shipping')
plt.xlabel('log(price+1)', fontsize=12)
plt.ylabel('frequency', fontsize=12)
plt.title('Price Distribution by Shipping Type', fontsize=15)
plt.tick_params(labelsize=12)
plt.legend()
plt.show()

# %% [markdown]
# It is obvious that the average price is higher when buyer pays shipping.

# %% [markdown]
# ## Category Names

# %% [markdown]
# ### Category names

# %%
print('There are', train['category_name'].nunique(), 'unique values in category name column')
# Out:
# There are 1267 unique values in category name column

# %% [markdown]
# Top 10 most common category names

# %%
train['category_name'].value_counts()[:10]
# Out:
# Women/Athletic Apparel/Pants, Tights, Leggings                 48180
# Women/Tops & Blouses/T-Shirts                                  37084
# Beauty/Makeup/Face                                             27511
# Beauty/Makeup/Lips                                             23906
# Electronics/Video Games & Consoles/Games                       21289
# Beauty/Makeup/Eyes                                             20110
# Electronics/Cell Phones & Accessories/Cases, Covers & Skins    19596
# Women/Underwear/Bras                                           17075
# Women/Tops & Blouses/Blouse                                    16211
# Women/Tops & Blouses/Tank, Cami                                16167
# Name: category_name, dtype: int64

# %% [markdown]
# ### Item condition vs. Price

# %%
sns.boxplot(x = 'item_condition_id', y = np.log(train['price']+1), data = train, palette = sns.color_palette('RdBu',5))

# %% [markdown]
# There seems to be various on the average price between each item condition id.

# %% [markdown]
# Therefore, we are going to use all the features to build our model.

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## Settings

# %%
NUM_BRANDS = 4000
NUM_CATEGORIES = 1000
NAME_MIN_DF = 10
MAX_FEATURES_ITEM_DESCRIPTION = 50000

# %% [markdown]
# There are missing values in the columns.

# %%
print('There are %d items that do not have a category name.' %train['category_name'].isnull().sum())
# Out:
# There are 5056 items that do not have a category name.

# %%
print('There are %d items that do not have a brand name.' %train['brand_name'].isnull().sum())
# Out:
# There are 505934 items that do not have a brand name.

# %%
print('There are %d items that do not have a description.' %train['item_description'].isnull().sum())
# Out:
# There are 4 items that do not have a description.

# %%
def handle_missing_inplace(dataset): 
    dataset['category_name'].fillna(value='missing', inplace=True) 
    dataset['brand_name'].fillna(value='missing', inplace=True) 
    dataset['item_description'].replace('No description yet,''missing', inplace=True) 
    dataset['item_description'].fillna(value='missing', inplace=True)

# %%
def cutting(dataset):
    pop_brand = dataset['brand_name'].value_counts().loc[lambda x: x.index != 'missing'].index[:NUM_BRANDS]
    dataset.loc[~dataset['brand_name'].isin(pop_brand), 'brand_name'] = 'missing'
    pop_category = dataset['category_name'].value_counts().loc[lambda x: x.index != 'missing'].index[:NUM_CATEGORIES]

# %%
def to_categorical(dataset):
    dataset['category_name'] = dataset['category_name'].astype('category')
    dataset['brand_name'] = dataset['brand_name'].astype('category')
    dataset['item_condition_id'] = dataset['item_condition_id'].astype('category')

# %%
df = pd.read_csv('/content/drive/My Drive/train.tsv', sep = '\t')
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]
test_new = test.drop('price', axis=1)
y_test = np.log1p(test["price"])

# %% [markdown]
# Drop rows where price = 0

# %%
train = train[train.price != 0].reset_index(drop=True)

# %%
nrow_train = train.shape[0]
y = np.log1p(train["price"])
merge: pd.DataFrame = pd.concat([train, test_new])

# %%
handle_missing_inplace(merge)
cutting(merge)
to_categorical(merge)

# %%
merge.head()
# Out:
#    train_id  ...                                   item_description
# 0         0  ...                                 No description yet
# 1         1  ...  This keyboard is in great condition and works ...
# 2         2  ...  Adorable top with a hint of lace and a key hol...
# 3         3  ...  New with tags. Leather horses. Retail for [rm]...
# 4         4  ...          Complete with certificate of authenticity
#
# [5 rows x 8 columns]

# %% [markdown]
# Count vectorize name and category name columns.

# %%
cv = CountVectorizer(min_df=NAME_MIN_DF)
X_name = cv.fit_transform(merge['name'])

# %%
cv = CountVectorizer()
X_category = cv.fit_transform(merge['category_name'])

# %% [markdown]
# TFIDF Vectorize item_description column.

# %%
tv = TfidfVectorizer(max_features=MAX_FEATURES_ITEM_DESCRIPTION, ngram_range=(1, 3), stop_words='english')
X_description = tv.fit_transform(merge['item_description'])

# %% [markdown]
# Label binarize brand_name column.

# %%
lb = LabelBinarizer(sparse_output=True)
X_brand = lb.fit_transform(merge['brand_name'])

# %% [markdown]
# Create dummy variables for item_condition_id and shipping columns.

# %%
X_dummies = csr_matrix(pd.get_dummies(merge[['item_condition_id', 'shipping']], sparse=True).values)

# %% [markdown]
# Create sparse merge.

# %%
sparse_merge = hstack((X_dummies, X_description, X_brand, X_category, X_name)).tocsr()

# %%
sparse_merge.shape
# Out:
# (1481852, 72753)

# %% [markdown]
# Remove features with document frequency <=1.

# %%
mask = np.array(np.clip(sparse_merge.getnnz(axis=0) - 1, 0, 1), dtype=bool)
sparse_merge = sparse_merge[:, mask]

# %%
sparse_merge.shape
# Out:
# (1481852, 72287)

# %% [markdown]
# Separate train and test data from sparse merge.

# %%
X = sparse_merge[:nrow_train]
X_test = sparse_merge[nrow_train:]

# %%
train_X = lgb.Dataset(X, label=y)

# %%
params = {
        'learning_rate': 0.75,
        'application': 'regression',
        'max_depth': 3,
        'num_leaves': 100,
        'verbosity': -1,
        'metric': 'RMSE',
    }

# %% [markdown]
# ### Training
# Training a model requires a parameter list and data set. And training will take a while.

# %%
gbm = lgb.train(params, train_set=train_X, num_boost_round=3200, verbose_eval=100)

# %% [markdown]
# ### Prediction

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

# %%
from sklearn.metrics import mean_squared_error
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# The rmse of prediction is: 0.46162543539245154
