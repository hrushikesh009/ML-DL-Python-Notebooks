# %%
pip install turicreate

# %%
from __future__ import division
import turicreate as tc
import math
import string

# %%
products = tc.SFrame('/content/drive/My Drive/amazon_baby.sframe/')
products
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
#
# Rows: 183531
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |    Planetwise Flannel Wipes   | These flannel wipes are OK... |  3.0   |
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# | A Tale of Baby's Days with... | Lovely book, it's bound ti... |  4.0   |
# | Baby Tracker&reg; - Daily ... | Perfect for new parents. W... |  5.0   |
# ...

# %% [markdown]
# Building a word count vector for each review

# %%
import string 
def remove_punctuation(text):
    translator = text.maketrans('', '', string.punctuation)
    text = text.translate(translator)
    return text

# %%
review_without_punctuation = products['review'].apply(remove_punctuation)
products['word_count'] = tc.text_analytics.count_words(review_without_punctuation)

# %%
products
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
#
# Rows: 183531
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |    Planetwise Flannel Wipes   | These flannel wipes are OK... |  3.0   |
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# | A Tale of Baby's Days with... | Lovely book, it's bound ti... |  4.0   |
# | Baby Tracker&reg; - Daily ... | Perfect for new parents. W... |  5.0   |
# ...

# %%
products = products[products['rating'] !=3]
products
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
#
# Rows: Unknown
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# | A Tale of Baby's Days with... | Lovely book, it's bound ti... |  4.0   |
# | Baby Tracker&reg; - Daily ... | Perfect for new parents. W... |  5.0   |
# | Baby Tracker&reg; - Daily ... | A friend of mine pinned th... |  5.0   |
# ...

# %%
products['sentiment'] = products['rating'].apply(lambda rating : +1 if rating > 3 else -1)
products
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	sentiment	int
#
# Rows: 166752
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |     Planetwise Wipe Pouch     | it came early and was not ... |  5.0   |
# | Annas Dream Full Quilt wit... | Very soft and comfortable ... |  5.0   |
# | Stop Pacifier Sucking with... | This is a product well wor... |  5.0   |
# | Stop Pacifier Sucking with... | All of my kids have cried ... |  5.0   |
# | Stop Pacifier Sucking with... | When the Binky Fairy came ... |  5.0   |
# | A Tale of Baby's Days with... | Lovely book, it's bound ti... |  4.0   |
# | Baby Tracker&reg; - Daily ... | Perfect for new parents. W... |  5.0   |
# | Baby Tracker&reg; - Daily ... | A friend of mine pinned th... |  5.0   |
# ...

# %%
train_data, test_data = products.random_split(.8, seed=1)
print(len(train_data))
print(len(test_data))
# Out:
# 133416
# 33336

# %%
sentiment_model = tc.logistic_classifier.create(train_data,target='sentiment',features=['word_count'],validation_set=None)
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 133416
# Number of classes           : 2
# Number of feature columns   : 1
# Number of unpacked features : 121712
# Number of coefficients      : 121713
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+
# | 0         | 4        | 0.250000  | 1.458902     | 0.840754          |
# | 1         | 9        | 3.250000  | 3.443293     | 0.941514          |
# | 2         | 11       | 2.778177  | 4.383493     | 0.942638          |
# | 3         | 12       | 2.778177  | 4.977194     | 0.967822          |
# | 4         | 13       | 2.778177  | 5.564824     | 0.976495          |
# ...

# %%
sentiment_model
# Out:
# Class                          : LogisticClassifier
#
# Schema
# ------
# Number of coefficients         : 121713
# Number of examples             : 133416
# Number of classes              : 2
# Number of feature columns      : 1
# Number of unpacked features    : 121712
#
# Hyperparameters
# ---------------
# L1 penalty                     : 0.0
# L2 penalty                     : 0.01
#
# Training Summary
# ----------------
# Solver                         : lbfgs
# Solver iterations              : 5
# Solver status                  : TERMINATED: Terminated due to numerical difficulties.
# Training time (sec)            : 4.9964
#
# Settings
# --------
# Log-likelihood                 : inf
#
# Highest Positive Coefficients
# -----------------------------
# word_count[offsi]              : 21.7657
# word_count[conclusions]        : 21.6818
# word_count[torsional]          : 21.6818
# word_count[geeeezzz]           : 21.6818
# word_count[articletest]        : 21.6818
#
# ...

# %%
weights = sentiment_model.coefficients
weights
# Out:
# Columns:
# 	name	str
# 	index	str
# 	class	int
# 	value	float
# 	stderr	float
#
# Rows: 121713
#
# Data:
# +-------------+--------------+-------+-----------------------+--------+
# |     name    |    index     | class |         value         | stderr |
# +-------------+--------------+-------+-----------------------+--------+
# | (intercept) |     None     |   1   |   0.7797362814630167  |  None  |
# |  word_count |  recommend   |   1   |  0.30524577375580586  |  None  |
# |  word_count |    highly    |   1   |   0.906063622151134   |  None  |
# |  word_count | disappointed |   1   |   -2.426792494486638  |  None  |
# |  word_count |     love     |   1   |   0.8405057320631628  |  None  |
# |  word_count |      it      |   1   |  0.010479446044391135 |  None  |
# |  word_count |    planet    |   1   |  -0.38467299112565845 |  None  |
# |  word_count |     and      |   1   |  0.03631437278677278  |  None  |
# |  word_count |     bags     |   1   |  0.13057598098929238  |  None  |
# ...

# %%
weights['value']
# Out:
# dtype: float
# Rows: 121713
# ...

# %%
num_positive_weights = (weights['value'] >= 0).sum()
num_negative_weights = (weights['value'] < 0).sum()

print("Number of positive weights: %s " % num_positive_weights)
print("Number of negative weights: %s " % num_negative_weights)
# Out:
# Number of positive weights: 91073
# Number of negative weights: 30640

# %%
sample_test_data = test_data[10:13]
print(sample_test_data['rating'])
sample_test_data
# Out:
# [5.0, 2.0, 1.0]
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	sentiment	int
#
# Rows: 3
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# |   Our Baby Girl Memory Book   | Absolutely love it and all... |  5.0   |
# | Wall Decor Removable Decal... | Would not purchase again o... |  2.0   |
# | New Style Trailing Cherry ... | Was so excited to get this... |  1.0   |
# +-------------------------------+-------------------------------+--------+
# +-------------------------------+-----------+
# |           word_count          | sentiment |
# +-------------------------------+-----------+
# | {'again': 1.0, 'book': 1.0... |     1     |
# | {'peeling': 1.0, '5': 1.0,... |     -1    |
# | {'on': 1.0, 'waste': 1.0, ... |     -1    |
# ...

# %%
sample_test_data[0]['review']
# Out:
# 'Absolutely love it and all of the Scripture in it.  I purchased the Baby Boy version for my grandson when he was born and my daughter-in-law was thrilled to receive the same book again.'

# %%
scores = sentiment_model.predict(sample_test_data, output_type='margin')
print(scores)
# Out:
# [4.788907309204978, -3.00078222242151, -8.188501360764477]

# %%
def class_predictions(scores):
  prediction = []
  for value in scores:
    if value > 0:
      prediction.append(1)
    elif value <= 0:
      prediction.append(-1)
  return prediction

# %%
class_predictions(scores)
# Out:
# [1, -1, -1]

# %%
print("Class predictions according to Turi Create:")
print(sentiment_model.predict(sample_test_data))
# Out:
# Class predictions according to Turi Create:
# [1, -1, -1]

# %%
def probability_predictions(scores):
  prob_prediction = []
  for value in scores:
    pred = 1/(1 + math.exp(-value))
    prob_prediction.append(pred)
  return prob_prediction

# %%
probability_predictions(scores)
# Out:
# [0.9917471313286145, 0.04739054748897279, 0.00027775277121678676]

# %%
print("Class predictions according to Turi Create:")
print(sentiment_model.predict(sample_test_data, output_type='probability'))
# Out:
# Class predictions according to Turi Create:
# [0.9917471313286145, 0.0473905474889728, 0.00027775277121678665]

# %%
test_data
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	sentiment	int
#
# Rows: 33336
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# | Baby Tracker&reg; - Daily ... | This has been an easy way ... |  4.0   |
# | Baby Tracker&reg; - Daily ... | I love this journal and ou... |  4.0   |
# | Nature's Lullabies First Y... | I love this little calende... |  5.0   |
# | Nature's Lullabies Second ... | I had a hard time finding ... |  5.0   |
# |  Lamaze Peekaboo, I Love You  | One of baby's first and fa... |  4.0   |
# |  Lamaze Peekaboo, I Love You  | My son loved this book as ... |  5.0   |
# |  Lamaze Peekaboo, I Love You  | Our baby loves this book &... |  5.0   |
# | SoftPlay Giggle Jiggle Fun... | This bear is absolutely ad... |  2.0   |
# ...

# %%
test_data['prob_predictions'] = sentiment_model.predict(test_data, output_type='probability')
test_data
# Out:
# Columns:
# 	name	str
# 	review	str
# 	rating	float
# 	word_count	dict
# 	sentiment	int
# 	prob_predictions	float
#
# Rows: 33336
#
# Data:
# +-------------------------------+-------------------------------+--------+
# |              name             |             review            | rating |
# +-------------------------------+-------------------------------+--------+
# | Baby Tracker&reg; - Daily ... | This has been an easy way ... |  4.0   |
# | Baby Tracker&reg; - Daily ... | I love this journal and ou... |  4.0   |
# | Nature's Lullabies First Y... | I love this little calende... |  5.0   |
# | Nature's Lullabies Second ... | I had a hard time finding ... |  5.0   |
# |  Lamaze Peekaboo, I Love You  | One of baby's first and fa... |  4.0   |
# |  Lamaze Peekaboo, I Love You  | My son loved this book as ... |  5.0   |
# |  Lamaze Peekaboo, I Love You  | Our baby loves this book &... |  5.0   |
# | SoftPlay Giggle Jiggle Fun... | This bear is absolutely ad... |  2.0   |
# ...

# %%
test_data['name','prob_predictions'].topk('prob_predictions', k=20).print_rows(20)
# Out:
# +-------------------------------+------------------+
# |              name             | prob_predictions |
# +-------------------------------+------------------+
# | Maxi-Cosi Pria 70 with Tin... |       1.0        |
# | Mamas &amp; Papas 2014 Urb... |       1.0        |
# | Barin Toys Teething Pendan... |       1.0        |
# | CTA Digital 2-in-1 iPotty ... |       1.0        |
# | Alva Baby One Size Washabl... |       1.0        |
# | Graco FastAction Fold Jogg... |       1.0        |
# | Britax Boulevard 70-G3 Con... |       1.0        |
# | The Original CJ's BuTTer (... |       1.0        |
# | Diono RadianRXT Convertibl... |       1.0        |
# | Diono RadianRXT Convertibl... |       1.0        |
# | Britax Decathlon Convertib... |       1.0        |
# | Quinny 2012 Buzz Stroller,... |       1.0        |
# | Roan Rocco Classic Pram St... |       1.0        |
# | Baby Einstein Around The W... |       1.0        |
# | Britax Frontier Booster Ca... |       1.0        |
# ...

# %%
test_data['name','prob_predictions'].topk('prob_predictions', k=20,reverse = True).print_rows(20)
# Out:
# +-------------------------------+------------------------+
# |              name             |    prob_predictions    |
# +-------------------------------+------------------------+
# | Luna Lullaby Bosom Baby Nu... | 3.2297908371800465e-63 |
# | The First Years True Choic... | 1.6322823186413695e-24 |
# | Jolly Jumper Arctic Sneak ... | 8.110311376808403e-20  |
# | Motorola MBP36 Remote Wire... | 7.797281600636349e-16  |
# | VTech Communications Safe ... | 1.841161478528488e-14  |
# | Fisher-Price Ocean Wonders... | 6.345094942115024e-14  |
# | Levana Safe N'See Digital ... | 6.578528511903649e-14  |
# | Safety 1st High-Def Digita... | 1.540841000856099e-13  |
# | Snuza Portable Baby Moveme... | 6.301835284302375e-13  |
# | Adiri BPA Free Natural Nur... | 9.314560911103444e-13  |
# | Samsung SEW-3037W Wireless... | 5.920602966716171e-12  |
# | Motorola Digital Video Bab... | 5.986200846184087e-12  |
# | Cloth Diaper Sprayer--styl... | 1.0091402074339824e-11 |
# ...

# %%
def get_classification_accuracy(model, data, true_labels):
    # First get the predictions
    prediction = model.predict(data)
    
    # Compute the number of correctly classified examples
    correct_prediction = 0
    num_correct = sum(prediction == true_labels)
    

    # Then compute accuracy by dividing num_correct by total number of examples
    accuracy = num_correct/len(data)
    return accuracy

# %%
get_classification_accuracy(sentiment_model, test_data, test_data['sentiment'])
# Out:
# 0.9221862251019919

# %% [markdown]
# Learn another classifier with fewer words

# %%
significant_words = ['love', 'great', 'easy', 'old', 'little', 'perfect', 'loves', 
      'well', 'able', 'car', 'broke', 'less', 'even', 'waste', 'disappointed', 
      'work', 'product', 'money', 'would', 'return']

# %%
train_data['word_count_subset'] = train_data['word_count'].dict_trim_by_keys(significant_words, exclude=False)
test_data['word_count_subset'] = test_data['word_count'].dict_trim_by_keys(significant_words, exclude=False)

# %%
train_data[0]['review']
# Out:
# 'it came early and was not disappointed. i love planet wise bags and now my wipe holder. it keps my osocozy wipes moist and does not leak. highly recommend it.'

# %%
print(train_data[0]['word_count'])
# Out:
# {'recommend': 1.0, 'highly': 1.0, 'disappointed': 1.0, 'love': 1.0, 'it': 3.0, 'planet': 1.0, 'and': 3.0, 'bags': 1.0, 'wipes': 1.0, 'not': 2.0, 'early': 1.0, 'came': 1.0, 'i': 1.0, 'does': 1.0, 'wise': 1.0, 'my': 2.0, 'was': 1.0, 'now': 1.0, 'wipe': 1.0, 'holder': 1.0, 'leak': 1.0, 'keps': 1.0, 'osocozy': 1.0, 'moist': 1.0}

# %%
print(train_data[0]['word_count_subset'])
# Out:
# {'disappointed': 1.0, 'love': 1.0}

# %%
simple_model = tc.logistic_classifier.create(train_data,
                                                     target = 'sentiment',
                                                     features=['word_count_subset'],
                                                     validation_set=None)
simple_model
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 133416
# Number of classes           : 2
# Number of feature columns   : 1
# Number of unpacked features : 20
# Number of coefficients      : 21
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+-------------------+
# | Iteration | Passes   | Elapsed Time | Training Accuracy |
# +-----------+----------+--------------+-------------------+
# | 1         | 2        | 0.376580     | 0.862917          |
# | 2         | 3        | 0.595869     | 0.865713          |
# | 3         | 4        | 0.813672     | 0.866478          |
# | 4         | 5        | 1.023253     | 0.866748          |
# | 5         | 6        | 1.237760     | 0.866815          |
# | 6         | 7        | 1.450991     | 0.866815          |
# +-----------+----------+--------------+-------------------+
# SUCCESS: Optimal solution found.
# ...

# %%
get_classification_accuracy(simple_model, test_data, test_data['sentiment'])
# Out:
# 0.8693004559635229

# %%
simple_weights = simple_model.coefficients.sort('value', ascending=False)

# %%
num_simple_positive_weights = (simple_weights['value'] > 0)
num_simple_negative_weights = (simple_weights['value'] < 0)

print("Number of positive weights: %s " % num_simple_positive_weights.sum())
print("Number of negative weights: %s " % num_simple_negative_weights.sum())
# Out:
# Number of positive weights: 11
# Number of negative weights: 10

# %%
simple_weights = simple_model.coefficients
positive_significant_words = simple_weights[(simple_weights['value'] > 0) & (simple_weights['name'] == "word_count_subset")]['index']
print(len(positive_significant_words))
print(positive_significant_words)
# Out:
# 10
# ['love', 'well', 'loves', 'little', 'easy', 'great', 'able', 'perfect', 'old', 'car']

# %%
weights.filter_by(positive_significant_words, 'index')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	class	int
# 	value	float
# 	stderr	float
#
# Rows: 10
#
# Data:
# +------------+---------+-------+---------------------+--------+
# |    name    |  index  | class |        value        | stderr |
# +------------+---------+-------+---------------------+--------+
# | word_count |   love  |   1   |  0.8405057320631628 |  None  |
# | word_count |   well  |   1   |  0.4010755749238931 |  None  |
# | word_count |  loves  |   1   |  0.9749823125149898 |  None  |
# | word_count |  little |   1   |  0.4099316272590621 |  None  |
# | word_count |   easy  |   1   |  0.7349826255685785 |  None  |
# | word_count |  great  |   1   |  0.778953288381427  |  None  |
# | word_count |   able  |   1   | 0.10752802191587757 |  None  |
# | word_count | perfect |   1   |  1.0447994204060913 |  None  |
# | word_count |   old   |   1   | 0.07967490900991056 |  None  |
# | word_count |   car   |   1   | 0.11965787650846002 |  None  |
# ...

# %% [markdown]
# Comparing models

# %%
get_classification_accuracy(simple_model, train_data, train_data['sentiment'])
# Out:
# 0.8668150746537147

# %%
get_classification_accuracy(sentiment_model, train_data, train_data['sentiment'])
# Out:
# 0.976494573364514

# %%
get_classification_accuracy(simple_model, test_data, test_data['sentiment'])
# Out:
# 0.8693004559635229

# %%
get_classification_accuracy(sentiment_model, test_data, test_data['sentiment'])
# Out:
# 0.9221862251019919

# %%
num_positive  = (train_data['sentiment'] == +1).sum()
num_negative = (train_data['sentiment'] == -1).sum()
print(num_positive)
print(num_negative)
# Out:
# 112164
# 21252

# %%
print ((test_data['sentiment'] == +1).sum())
print ((test_data['sentiment'] == -1).sum())
# Out:
# 28095
# 5241

# %%
print((test_data['sentiment'] == +1).sum()/len(test_data['sentiment']))
# Out:
# 0.8427825773938085
